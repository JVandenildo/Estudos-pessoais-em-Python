# %% [markdown]
# This is a jupyter notebook, it is worth noticing the `.ipynb` file extension. On a jupyter notebook there is two kinds of sections (called cells), one kind is for python code the other is for texts (all text sections are in markdown).

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Jupyter notebooks are handy because it shows code, plain texts (thought process) and the output of the code. Another great usage of jupyter notebooks is execute bits of the code instead of running it all.
# But the cells' sequence is important. For example:

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 1, 2, 3, 5, 8]
y = [1, 2, 3, 4, 5, 6]

plt.plot(x, y)
plt.show()

# %% [markdown]
# Jupyter notebooks may be used locally using text editors/IDEs like [Spyder](https://www.spyder-ide.org/) or [Visual Studio Code](https://code.visualstudio.com/), or on cloud platforms like [Google Colab](https://colab.research.google.com/) and [kaggle](https://www.kaggle.com/).
