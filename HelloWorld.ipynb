# %% [markdown]
# This is a jupyter notebook, it is worth noticing the `.ipynb` file extension. On a jupyter notebook there is two kinds of sections (called cells), one kind is for python code the other is for texts (all text sections are in markdown).

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Jupyter notebooks are handy because it shows code, plain texts (thought process) and the result of the code. But the cells' order is important. For example:

# %%
from matplotlib import pyplot as plt

# %%
x = [27, 32, 34, 62, 63]
y = [96, 91, 89, 61, 60]

plt.plot(x, y)
plt.show()

# %% [markdown]
# Another great usage of jupyter notebooks is execute bits of the code instead of running it all.
